# %%
import pandas as pd

file_path = "/content/drive/MyDrive/car details v4.csv"

df = pd.read_csv(file_path)
df
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %% [markdown]
# menampilkan sepuluh baris pertama pada Vehicle dataset

# %%
df.head(10)
# Out:
#             Make                                 Model    Price  Year  \
# 0          Honda                   Amaze 1.2 VX i-VTEC   505000  2017
# 1  Maruti Suzuki                       Swift DZire VDI   450000  2014
# 2        Hyundai                  i10 Magna 1.2 Kappa2   220000  2011
# 3         Toyota                              Glanza G   799000  2019
# 4         Toyota       Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# 5  Maruti Suzuki                              Ciaz ZXi   675000  2017
# 6  Mercedes-Benz                  CLA 200 Petrol Sport  1898999  2015
# 7            BMW                  X1 xDrive20d M Sport  2650000  2017
# 8          Skoda  Octavia 1.8 TSI Style Plus AT [2017]  1390000  2017
# 9         Nissan                        Terrano XL (D)   575000  2015
#
#    Kilometer Fuel Type Transmission    Location   Color   Owner Seller Type  \
# 0      87150    Petrol       Manual        Pune    Grey   First   Corporate
# ...

# %% [markdown]
# menampilkan baris terakhir dari Vehicle dataset

# %%
df.tail()
# Out:
#           Make                                  Model    Price  Year  \
# 2054  Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055   Hyundai                           Eon D-Lite +   275000  2014
# 2056      Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057       BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058  Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# 2054      90300    Diesel       Manual       Surat   White   First
# 2055      83000    Petrol       Manual   Ahmedabad   White  Second
# 2056      73000    Petrol       Manual       Thane  Silver   First
# 2057      60474    Diesel    Automatic  Coimbatore   White   First
# 2058      72000    Diesel       Manual    Guwahati   White   First
#
#      Seller Type   Engine           Max Power         Max Torque Drivetrain  \
# ...

# %% [markdown]
# menampilkan tipe data dan menampilkan jumlah baris dan kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %% [markdown]
# Menghitung jumlah kolom dan baris pada Vehicle dataset

# %%
df.shape
# Out:
# (2059, 20)

# %% [markdown]
# Tipe data dari Vehicle dataset

# %%
df.dtypes
# Out:
# Make                   object
# Model                  object
# Price                   int64
# Year                    int64
# Kilometer               int64
# Fuel Type              object
# Transmission           object
# Location               object
# Color                  object
# Owner                  object
# Seller Type            object
# Engine                 object
# Max Power              object
# Max Torque             object
# Drivetrain             object
# Length                float64
# Width                 float64
# Height                float64
# Seating Capacity      float64
# Fuel Tank Capacity    float64
# dtype: object

# %% [markdown]
# Menampilkan ringkasan statistik

# %%
df.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# BUSINESS UNDERSTANDING

# %% [markdown]
# # Busines Objective
#
#
# 1. Prediksi Harga Kendaraan (Price Prediction)
#
#  Tujuan: Membantu dealer atau platform jual-beli mobil dalam menentukan harga yang kompetitif berdasarkan spesifikasi kendaraan, tahun produksi, dan kondisi pasar.
#
#  Manfaat:Meningkatkan transparansi harga dan Memaksimalkan keuntungan penjualan Membantu pembeli mendapatkan harga terbaik
#
# 2. Analisis Depresiasi Harga Kendaraan
#
#  Tujuan: Memahami bagaimana nilai kendaraan turun dari waktu ke waktu berdasarkan faktor seperti merek, model, tahun produksi, dan jarak tempuh.
#
#  Manfaat: Membantu pelanggan memahami kapan waktu terbaik untuk membeli atau menjual mobil Memberikan wawasan kepada perusahaan leasing tentang nilai kendaraan bekas
#
# 3. Rekomendasi Kendaraan kepada Pelanggan
#
# Tujuan: Mengembangkan sistem rekomendasi untuk membantu pelanggan memilih mobil yang sesuai dengan kebutuhan dan anggaran mereka.
#
# manfaat:Meningkatkan pengalaman pengguna pada platform jual-beli kendaraan

# %% [markdown]
# # Asses Situation
#
# Mengidentifikasi potensi tantangan dalam analisis dataset kendaraan.
#
# Data Tidak Seimbang (Imbalanced Data): Apakah sebagian besar kendaraan berasal dari merek tertentu, sehingga membuat prediksi sulit bagi merek lain?
#
# Outliers: Apakah ada harga kendaraan yang terlalu tinggi/rendah sehingga bisa mengganggu analisis?
#
# Fitur yang Tidak Relevan: Apakah ada kolom yang tidak berguna dalam analisis bisnis?

# %% [markdown]
# # Data Mining Goals
#
#
# Analisis Tren dan Preferensi Konsumen (Customer Preference Analysis)
#
# Tujuan: Menganalisis tren preferensi pembeli mobil berdasarkan faktor seperti merek, model, bahan bakar, harga, dll.
#
# Manfaat Bisnis:
#
# Dealer mobil dapat mengetahui model atau merek yang paling diminati.
# Perusahaan ride-sharing dapat menentukan jenis kendaraan terbaik untuk armada mereka.
# Marketplace mobil bisa menyesuaikan strategi pemasaran berdasarkan tren konsumen.
